# %% [markdown]
# <a href="https://colab.research.google.com/github/Yaswanth2539/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-06-14 17:31:46--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   149MB/s    in 0.5s
#
# 2023-06-14 17:31:51 (149 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 2950   1802.02186v1  Inception and the Resnet family of Convolution...    cs
# 38323  1606.02440v1  Current research in lifelog data has not paid ...    cs
# 13696   1112.2183v1  Customer Relationship Management becomes a lea...    cs
# 6813   1706.04161v1  The Gumbel trick is a method to sample from a ...  stat
# 19641   1210.7002v1  In this paper we present the results of unstru...    cs
# ...             ...                                                ...   ...
# 13095  1509.08990v1  We analyze a model of learning and belief form...    cs
# 5317    1301.2656v1  In this paper we present a nonparametric metho...  stat
# 21663   1306.3530v2  This paper generalizes beta divergence beyond ...  stat
# 21536   0912.1618v1  In this paper, we consider the problem of "hyp...  stat
# 36387   1302.6787v1  We show how to find a small loop curser in a B...    cs
#
#                                                    title  year  \
# 2950                                             FastNet  2018
# 38323  On the Place of Text Data in Lifelogs, and Tex...  2016
# 13696  The Expert System Designed to Improve Customer...  2011
# 6813                  Lost Relatives of the Gumbel Trick  2017
# 19641  A Biomimetic Approach Based on Immune Systems ...  2012
# ...                                                  ...   ...
# 13095  Learning without Recall: A Case for Log-Linear...  2015
# 5317   Multiple functional regression with both discr...  2013
# 21663                        Generalized Beta Divergence  2013
# 21536                   Hyper-sparse optimal aggregation  2009
# 36387  Approximation Algorithms for the Loop Cutset P...  2013
#
#                                                 keywords
# 2950   [inception, convolutional, computational, infe...
# 38323  [attention, cognitive, activities, comparison,...
# 13696  [relationship, management, competitive, enviro...
# 6813   [probability, distribution, normalizing, parti...
# 19641  [unstructured, clustering, biomimetic, experim...
# ...                                                  ...
# 13095  [formation, observations, inferences, observat...
# 5317   [nonparametric, extending, functional, regress...
# 21663  [generalizes, divergence, classical, associate...
# 21536  [aggregation, dictionary, functions, aggregati...
# 36387  [conditioning, inference, algorithm, guarantee...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 2950     [inception, convolutional, computational, infe...
# 38323    [attention, cognitive, activities, comparison,...
# 13696    [relationship, management, competitive, enviro...
# 6813     [probability, distribution, normalizing, parti...
# 19641    [unstructured, clustering, biomimetic, experim...
#                                ...
# 36755    [relentless, artificial, intelligence, increas...
# 38309    [derivation, frequencies, structure, derivatio...
# 37938    [optimization, hierarchical, thresholding, reg...
# 21949    [existence, topological, circularity, dimensio...
# 30835    [conceptually, geometrically, interpretable, o...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8769 words.
# Out of those 4554 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="665f8974-8e78-430e-ad3a-fcb15e4f9028" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("665f8974-8e78-430e-ad3a-fcb15e4f9028")) {                    Plotly.newPlot(                        "665f8974-8e78-430e-ad3a-fcb15e4f9028",                        [{"x":["applications","inference","architecture","inception","motivation","implementation","accuracies","controllers","comparison","architectures","deployment","competitive","efficiency","computational","convolutional","performing","impractical","currently","developed","analyzing","cognitive","quantifying","lifelogging","taxonomic","automatically","developing","detection","processing","vocabularies","increasingly","activities","prevalent","potentially","attention","significant","intellectual","selection","management","improving","decisions","requirements","validated","satisfaction","customers","appropriate","knowledge","collected","presented","environment","relationship","technique","different","information","capability","artificial","performance","objective","businesses","particular","perturbation","perturbations","sequential","analytical","additional","configuration","repeatedly","graphical","theoretical","distribution","probability","discussion","properties","typically","configurations","partition","normalizing","hybridization","experimenting","clustering","promising","classification","recommended","unstructured","experimental","statistics","asynchronous","triggering","explicitly","quantitatively","complicated","algorithms","applicable","beneficial","education","successes","implementing","practical","researchers","processes","systematically","summarizes","sequences","downloaded","supervision","techniques","challenge","generative","regression","parameters","consuming","experimentally","including","additionally","supervised","theoretically","demonstrate","functions","strategies","establish","programming","unavailable","generated","heuristics","expensive","therefore","discriminative","representing","multivariate","parametric","reconstruction","considering","increasing","inductive","approximating","transductive","algorithm","generalization","manuscript","formulating","chebyshev","compromise","acceptable","approximation","respectively","estimates","addresses","empirically","convergence","multidimensional","inequality","leveraging","minimization","guarantees","estimation","complexity","solutions","decompositions","distributions","introduce","exponential","components","polynomial","measurements","formulate","developments","motivated","estimating","alternating","recommendation","completion","construct","underlying","consistent","statistically","estimated","recognition","consistency","underline","annotated","fixations","complement","methodology","stability","automatic","communities","differences","movements","constraints","predicted","contributions","ecological","accurately","biological","alignment","available","hollywood","trainable","inconsistent","successfully","remarkable"],"y":[426,213,243,12,26,140,20,6,136,133,23,117,162,309,379,81,13,52,192,63,41,12,2,2,178,61,314,268,3,50,37,6,42,168,222,5,170,53,108,57,46,44,23,6,79,348,63,192,130,54,226,684,648,51,121,880,156,3,274,15,26,56,23,125,22,10,84,164,207,155,30,219,103,25,26,3,5,9,138,107,484,6,22,375,51,14,1,61,25,33,640,59,18,10,12,23,154,80,91,19,1,88,6,57,375,159,110,136,238,40,39,247,58,224,42,584,228,113,52,123,4,151,45,60,149,96,84,22,30,128,52,122,20,16,10,841,114,7,13,1,8,12,112,73,78,51,74,132,11,14,45,59,74,230,253,162,13,96,342,53,108,76,57,57,9,64,61,30,26,26,78,119,75,27,66,379,51,3,75,5,13,76,48,201,22,63,17,155,46,50,3,76,34,62,300,2,24,14,90,22],"type":"bar"},{"x":["applications","inference","architecture","inception","motiva ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4554,), (4554, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8033333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Statistical</span> <span style=''>keyword</span> <span style='background-color:rgba(0, 255, 0, 0.4776470588235294);'>detection</span> <span style=''>in</span> <span style=''>literary</span> <span style=''>corpora</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Understanding</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>human</span> <span style=''>language</span> <span style=''>requires</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>appropriate</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>words</span> <span style=''>in</span> <span style=''>texts</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.5522388059701493);'>retrieval</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.34513274336283184);'>detecting</span> <span style=''>and</span> <span style=''>ranking</span> <span style=''>the</span> <span style=''>relevant</span> <span style=''>words</span> <span style=''>of</span> <span style=''>a</span> <span style=''>text</span> <span style=''>by</span> <span style=''>means</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>referring</span> <span style=''>to</span> <span style=''>the</span> <span style=''>spatial</span> <span style=''>use</span> <span style=''>of</span> <span style=''>the</span> <span style=''>words</span> <span style=''>Shannons</span> <span style=''>entropy</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>is</span> <span style=''>used</span> <span style=''>as</span> <span style=''>a</span> <span style=''>tool</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.5764705882352942);'>automatic</span> <span style=''>keyword</span> <span style='background-color:rgba(0, 255, 0, 0.6564417177914111);'>extraction</span> <span style=''>By</span> <span style=''>using</span> <span style=''>The</span> <span style=''>Origin</span> <span style=''>of</span> <span style=''>Species</span> <span style=''>by</span> <span style=''>Charles</span> <span style=''>Darwin</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>representative</span> <span style=''>text</span> <span style=''>sample</span> <span style=''>we</span> <span style=''>show</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>our</span> <span style=''>detector</span> <span style=''>and</span> <span style=''>compare</span> <span style=''>it</span> <span style=''>with</span> <span style=''>another</span> <span style='background-color:rgba(0, 255, 0, 0.4054054054054055);'>proposals</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>The</span> <span style=''>random</span> <span style=''>shuffled</span> <span style=''>text</span> <span style=''>receives</span> <span style=''>special</span> <span style='background-color:rgba(0, 255, 0, 0.36032388663967607);'>attention</span> <span style=''>as</span> <span style=''>a</span> <span style=''>tool</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Fragmentation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>Tree</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ubiquitous</span> <span style=''>in</span> <span style=''>data</span> <span style=''>across</span> <span style=''>many</span> <span style=''>domains</span> <span style=''>and</span> <span style=''>many</span> <span style=''>datasets</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>naturally</span> <span style=''>modelled</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unobserved</span> <span style=''>tree</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>first</span> <span style=''>we</span> <span style=''>review</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fragmentation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>Bertoin</span> <span style=''>2006</span> <span style=''>and</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modelling</span> <span style=''>trees</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>the</span> <span style=''>popular</span> <span style=''>nested</span> <span style=''>Chinese</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restaurant</span> <span style=''>process</span> <span style=''>(nCRP)</span> <span style=''>Then</span> <span style=''>we</span> <span style=''>define</span> <span style=''>a</span> <span style=''>general</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>over</span> <span style=''>trees</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fragmentation</span> <span style=''>process</span> <span style=''>(DFP)</span> <span style=''>through</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>and</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fragmentation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>This</span> <span style=''>DFP</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>stick</span> <span style=''>breaking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construction</span> <span style=''>and</span> <span style=''>relates</span> <span style=''>to</span> <span style=''>the</span> <span style=''>nCRP</span> <span style=''>in</span> <span style=''>the</span> <span style=''>same</span> <span style=''>way</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style=''>process</span> <span style=''>relates</span> <span style=''>to</span> <span style=''>the</span> <span style=''>Chinese</span> <span style='background-color:rg ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>More</span> <span style=''>General</span> <span style=''>Robust</span> <span style=''>Loss</span> <span style=''>Function</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>viewed</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>many</span> <span style=''>popular</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>used</span> <span style=''>in</span> <span style=''>robust</span> <span style='background-color:rgba(255, 0, 0, 0.37804878048780494);'>statistics</span> <span style=''>the</span> <span style=''>CauchyLorentzian</span> <span style=''>Geman</span> <span style=''>McClure</span> <span style=''>WelschLeclerc</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalized</span> <span style=''>Charbonnier</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>(and</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>transitivity</span> <span style=''>the</span> <span style=''>L2</span> <span style=''>L1</span> <span style=''>L1</span> <span style=''>L2</span> <span style=''>and</span> <span style=''>pseudo</span> <span style=''>HuberCharbonnier</span> <span style=''>loss</span> <span style=''>functions)</span> <span style=''>If</span> <span style=''>this</span> <span style=''>penalty</span> <span style=''>is</span> <span style=''>viewed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>negative</span> <span style=''>log</span> <span style='background-color:rgba(255, 0, 0, 0.5059760956175299);'>likelihood</span> <span style=''>it</span> <span style=''>yields</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>that</span> <span style=''>includes</span> <span style=''>normal</span> <span style=''>and</span> <span style=''>Cauchy</span> <span style='background-color:rgba(255, 0, 0, 0.44347826086956527);'>distributions</span> <span style=''>as</span> <span style=''>special</span> <span style=''>cases</span> <span style=''>We</span> <span style=''>describe</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.36363636363636376);'>visualize</span> <span style=''>this</span> <span style=''>loss</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>and</span> <span style=''>document</span> <span style=''>several</span> <span style=''>of</span> <span style=''>their</span> <span style=''>useful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>denoising</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restoration</span> <span style=''>with</span> <span style=''>CNN</span> <span style=''>LSTM</span> <span style=''>Encoder</span> <span style=''>Decoder</span> <span style=''>with</span> <span style=''>Direct</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Attention</span> <br/><br/><span style=''>Image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>denoising</span> <span style=''>is</span> <span style=''>always</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>task</span> <span style=''>in</span> <span style=''>the</span> <span style=''>field</span> <span style=''>of</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>and</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>have</span> <span style=''>proposed</span> <span style=''>an</span> <span style=''>encoder</span> <span style=''>decoder</span> <span style=''>model</span> <span style=''>with</span> <span style=''>direct</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>which</span> <span style=''>is</span> <span style=''>capable</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>denoising</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruct</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrupted</span> <span style=''>images</span> <span style=''>Our</span> <span style=''>model</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>an</span> <span style=''>encoder</span> <span style=''>and</span> <span style=''>a</span> <span style=''>decoder</span> <span style=''>where</span> <span style=''>the</span> <span style=''>encoder</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>and</span> <span style=''>decoder</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multilayer</span> <span style=''>Long</span> <span style=''>Short</span> <span style=''>Term</span> <span style=''>memory</span> <span style=''>network</span> <span style=''>In</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>model</span> <span style=''>the</span> <span style=''>encoder</span> <span style=''>reads</span> <span style=''>an</span> <span style=''>image</span> <span style=''>and</span> <span style=''>catches</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>abstraction</span> <span style=''>of</span> <span style=''>that</span> <span style=''>image</span> <span style=''>in</span> <span style=''>a</span> <span style=''>vector</span> <span style=''>where</span> <span style=''>decoder</span> <span style=''>takes</span> <span style=''>that</span> <span style=''>vector</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrupted</span> <span style=''>image</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruct</span> <span style=''>a</span> <span style=''>clean</span> <span style=''>image</span> <span style=''>We</span> <span style=''>have</span> <span style=''>trained</span> <span style=''>our</span> <span style=''>model</span> <span style=''>on</span> <span style=''>MNIST</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>handwritt ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.125)
# 	architecture (0.08728448275862069)
# 	representation (0.1343390804597701)
# 	segmentation (0.07183908045977011)
# 	information (0.23275862068965517)
# 	detection (0.11278735632183907)
# 	experimental (0.13469827586206898)
# 	different (0.24568965517241378)
# 	convolutional (0.13613505747126436)
# 	recognition (0.13613505747126436)
#
# Some Statistics words are:
# 	stochastic (0.1349206349206349)
# 	variables (0.13740079365079366)
# 	estimation (0.17113095238095238)
# 	distributions (0.12351190476190477)
# 	theoretical (0.14831349206349206)
# 	statistical (0.15228174603174602)
# 	distribution (0.18898809523809523)
# 	inference (0.1974206349206349)
# 	dimensional (0.18998015873015872)
# 	regression (0.17906746031746032)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="962252e8-1b14-4bdb-b0e7-cefe891bc743" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("962252e8-1b14-4bdb-b0e7-cefe891bc743")) {                    Plotly.newPlot(                        "962252e8-1b14-4bdb-b0e7-cefe891bc743",                        [{"x":["applications","inference","architecture","inception","motivation","implementation","accuracies","controllers","comparison","architectures","deployment","competitive","efficiency","computational","convolutional","performing","impractical","currently","developed","analyzing","cognitive","quantifying","lifelogging","taxonomic","automatically","developing","detection","processing","vocabularies","increasingly","activities","prevalent","potentially","attention","significant","intellectual","selection","management","improving","decisions","requirements","validated","satisfaction","customers","appropriate","knowledge","collected","presented","environment","relationship","technique","different","information","capability","artificial","performance","objective","businesses","particular","perturbation","perturbations","sequential","analytical","additional","configuration","repeatedly","graphical","theoretical","distribution","probability","discussion","properties","typically","configurations","partition","normalizing","hybridization","experimenting","clustering","promising","classification","recommended","unstructured","experimental","statistics","asynchronous","triggering","explicitly","quantitatively","complicated","algorithms","applicable","beneficial","education","successes","implementing","practical","researchers","processes","systematically","summarizes","sequences","downloaded","supervision","techniques","challenge","generative","regression","parameters","consuming","experimentally","including","additionally","supervised","theoretically","demonstrate","functions","strategies","establish","programming","unavailable","generated","heuristics","expensive","therefore","discriminative","representing","multivariate","parametric","reconstruction","considering","increasing","inductive","approximating","transductive","algorithm","generalization","manuscript","formulating","chebyshev","compromise","acceptable","approximation","respectively","estimates","addresses","empirically","convergence","multidimensional","inequality","leveraging","minimization","guarantees","estimation","complexity","solutions","decompositions","distributions","introduce","exponential","components","polynomial","measurements","formulate","developments","motivated","estimating","alternating","recommendation","completion","construct","underlying","consistent","statistically","estimated","recognition","consistency","underline","annotated","fixations","complement","methodology","stability","automatic","communities","differences","movements","constraints","predicted","contributions","ecological","accurately","biological","alignment","available","hollywood","trainable","inconsistent","successfully","remarkable","relevance","operators","quantification","disorders","biomarkers","clinically","structures","monitoring","challenging","particularly","asymmetric","segmentation","pathological","imperfect","improvement","prescriptive","predominantly","stochastic","consisting","independent","computationally","identically","outperform","coefficient","distributed","prescribe","operational","asymptotically","framework","inventory","observations","optimization","harvested","analytics","experience","generally","associated","departure","quantities","tractable","specifically","leveraged","international","determination","auxiliary","perspective","predictive","operations","conditional","conditions","reflecting","representation","homogeneous","introdu ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	harvested
# 	collapsed
# 	recombine
# 	manipulations
# 	gracefully
# 	uninformative
# 	microwave
# 	epidemics
# 	explodingvanishing
# 	prognostic
# 	penalization
# 	grassmannian
# 	procrustes
# 	integrable
# 	preconditioned
# 	disentangles
# 	postulated
# 	couplings
# 	nontrivially
# 	andersson
# Some words which never appear in Statistics papers:
# 	lifelogging
# 	experimenting
# 	underline
# 	fixations
# 	ecological
# 	hollywood
# 	terminates
# 	existential
# 	reasoners
# 	termination
# 	undecidable
# 	summarising
# 	responders
# 	casualties
# 	transaction
# 	warehouse
# 	inflectional
# 	inflected
# 	productive
# 	memorable

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.086991418163858e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7675
